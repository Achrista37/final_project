# %%
# IMPORT Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
# Import the Australian Road Death Dataset
ardd_data = pd.read_csv('../Resources/ardd_fatal_crashes.csv')
ardd_data
# Out:
# /var/folders/h4/v2g57xvj6mz75vxd96qdxsqw0000gn/T/ipykernel_2989/2073364016.py:2: DtypeWarning: Columns (11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   ardd_data = pd.read_csv('../Resources/ardd_fatal_crashes.csv')
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20221049   NSW      3  2022    Tuesday  06:50     Single
# 1      20222018   Vic      3  2022     Friday  13:05   Multiple
# 2      20224006    SA      3  2022     Friday  09:30   Multiple
# 3      20225008    WA      3  2022   Saturday  06:00     Single
# 4      20226010   Tas      3  2022    Tuesday  11:47     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 48116  19892204   Vic      1  1989     Friday  13:20     Single
# 48117  19893326   Qld      1  1989     Monday  09:00   Multiple
# 48118  19892576   Vic      1  1989     Friday  17:15   Multiple
# 48119  19891122   NSW      1  1989    Tuesday  14:10   Multiple
# 48120  19894151    SA      1  1989  Wednesday  11:45   Multiple
#
#        Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  \
# 0                      1                No                           Yes
# 1                      1                -9                            -9
# 2                      1                No                            No
# 3                      1                No                            No
# 4                      1                No                            No
# ...                  ...               ...                           ...
# 48116                  1                No                            No
# 48117                  1                No                            -9
# 48118                  1                No                            No
# 48119                  1                No                            -9
# 48120                  1                No                            -9
#
#       Articulated Truck Involvement Speed Limit  National Remoteness Areas  \
# 0                                No          90   Inner Regional Australia
# 1                                -9          -9  Major Cities of Australia
# 2                                No          80   Outer Regional Australia
# 3                                No         110                        NaN
# 4                                No         100   Outer Regional Australia
# ...                             ...         ...                        ...
# 48116                            No          60                        NaN
# 48117                            No          60                        NaN
# 48118                            No          60                        NaN
# 48119                            No          60                        NaN
# 48120                            No          60                        NaN
#
#                    SA4 Name 2016 National LGA Name 2017  \
# 0                 Capital Region            Eurobodalla
# 1              Melbourne - Inner       Port Phillip (C)
# 2      South Australia - Outback       Port Augusta (C)
# 3                            NaN                    NaN
# 4      Launceston and North East        Break O'Day (M)
# ...                          ...                    ...
# 48116                        NaN                    NaN
# 48117                        NaN                    NaN
# 48118                        NaN                    NaN
# 48119                        NaN                    NaN
# 48120                        NaN                    NaN
#
#               National Road Type Christmas Period Easter Period Day of week  \
# 0                  Arterial Road               No            No     Weekday
# 1                     Local Road               No            No     Weekday
# 2      National or State Highway               No            No     Weekday
# 3                            NaN               No            No     Weekend
# 4      National or State Highway               No            No     Weekday
# ...                          ...              ...           ...         ...
# 48116                        NaN               No            No     Weekday
# 48117                        NaN               No            No     Weekday
# 48118                        NaN               No            No     Weekday
# 48119                        NaN               No            No     Weekday
# 48120                        NaN               No            No     Weekday
#
#       Time of Day
# 0             Day
# 1             Day
# 2             Day
# 3             Day
# 4             Day
# ...           ...
# 48116         Day
# 48117         Day
# 48118         Day
# 48119         Day
# 48120         Day
#
# [48121 rows x 20 columns]

# %%
#check the shape of the original CSV
ardd_data.shape
# Out:
# (48121, 20)

# %%
cleaned_ardd_data1 = ardd_data.filter(['State','Month','Year','Crash Type','Speed Limit','National Road Type','National Remoteness Areas', 'Christmas Period','Easter Period','Day of week','Time of Day'])
cleaned_ardd_data1.head(20)
# Out:
#    State  Month  Year Crash Type Speed Limit         National Road Type  \
# 0    NSW      3  2022     Single          90              Arterial Road
# 1    Vic      3  2022   Multiple          -9                 Local Road
# 2     SA      3  2022   Multiple          80  National or State Highway
# 3     WA      3  2022     Single         110                        NaN
# 4    Tas      3  2022     Single         100  National or State Highway
# 5    NSW      3  2022   Multiple          70  National or State Highway
# 6    NSW      3  2022     Single          60              Arterial Road
# 7    Vic      3  2022   Multiple          60          Sub-arterial Road
# 8    Vic      3  2022   Multiple         100              Arterial Road
# 9    Qld      3  2022     Single         100                 Local Road
# 10   Qld      3  2022     Single          60                 Local Road
# 11   NSW      3  2022     Single          70              Arterial Road
# 12   NSW      3  2022   Multiple         110  National or State Highway
# 13   Qld      3  2022     Single          50                 Local Road
# 14   Qld      3  2022     Single          -9                        NaN
# 15   Qld      3  2022   Multiple          60  National or State Highway
# 16   Qld      3  2022     Single          80  National or State Highway
# 17    WA      3  2022     Single         110                        NaN
# 18   NSW      3  2022   Multiple          50                 Local Road
# 19   NSW      3  2022     Single         100              Arterial Road
#
#     National Remoteness Areas Christmas Period Easter Period Day of week  \
# 0    Inner Regional Australia               No            No     Weekday
# 1   Major Cities of Australia               No            No     Weekday
# 2    Outer Regional Australia               No            No     Weekday
# 3                         NaN               No            No     Weekend
# 4    Outer Regional Australia               No            No     Weekday
# 5   Major Cities of Australia               No            No     Weekend
# 6   Major Cities of Australia               No            No     Weekend
# 7    Inner Regional Australia               No            No     Weekend
# 8    Inner Regional Australia               No            No     Weekend
# 9    Inner Regional Australia               No            No     Weekday
# 10  Major Cities of Australia               No            No     Weekday
# 11   Inner Regional Australia               No            No     Weekday
# 12   Inner Regional Australia               No            No     Weekday
# 13   Outer Regional Australia               No            No     Weekday
# 14   Inner Regional Australia               No            No     Weekday
# 15   Outer Regional Australia               No            No     Weekday
# 16  Major Cities of Australia               No            No     Weekday
# 17                        NaN               No            No     Weekend
# 18   Inner Regional Australia               No            No     Weekday
# 19           Remote Australia               No            No     Weekday
#
#    Time of Day
# 0          Day
# 1          Day
# 2          Day
# 3          Day
# 4          Day
# 5          Day
# 6          Day
# 7          Day
# 8          Day
# 9          Day
# 10       Night
# 11         Day
# 12         Day
# 13         Day
# 14         Day
# 15         Day
# 16         Day
# 17         Day
# 18         Day
# 19       Night

# %%
# according to the documentation, -9 would mean "Unknown", however after data exploration those data will be of no use for our ML model
cleaned_ardd_data1 = cleaned_ardd_data1.replace("-9", np.nan)

# %%
cleaned_ardd_data1 = cleaned_ardd_data1.replace("<40", 40)

# %%
cleaned_ardd_data1 = cleaned_ardd_data1.replace(100, 110)

# %%
cleaned_ardd_data1 = cleaned_ardd_data1.replace(60, 70)

# %%
cleaned_ardd_data1 = cleaned_ardd_data1.replace(70, 80)

# %%
cleaned_ardd_data1 = cleaned_ardd_data1.replace("Unspecified", np.nan)

# %%
#drop rows containing null values
cleaned_ardd_data1 = cleaned_ardd_data1.dropna()

# %%
#check shape 
cleaned_ardd_data1.shape
# Out:
# (7126, 11)

# %%
cleaned_ardd_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7126 entries, 0 to 8954
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      7126 non-null   object
#  1   Month                      7126 non-null   int64
#  2   Year                       7126 non-null   int64
#  3   Crash Type                 7126 non-null   object
#  4   Speed Limit                7126 non-null   object
#  5   National Road Type         7126 non-null   object
#  6   National Remoteness Areas  7126 non-null   object
#  7   Christmas Period           7126 non-null   object
#  8   Easter Period              7126 non-null   object
#  9   Day of week                7126 non-null   object
#  10  Time of Day                7126 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 668.1+ KB

# %%
cleaned_ardd_data1
# Out:
#      State  Month  Year Crash Type Speed Limit         National Road Type  \
# 0      NSW      3  2022     Single          90              Arterial Road
# 2       SA      3  2022   Multiple          80  National or State Highway
# 4      Tas      3  2022     Single         100  National or State Highway
# 5      NSW      3  2022   Multiple          70  National or State Highway
# 6      NSW      3  2022     Single          60              Arterial Road
# ...    ...    ...   ...        ...         ...                        ...
# 8936   Tas      1  2014   Multiple          80  National or State Highway
# 8944    WA      1  2014     Single         100  NATIONAL OR STATE HIGHWAY
# 8948    SA      1  2014     Single          50                 Local Road
# 8950    SA      1  2014     Single          50                 Local Road
# 8954    WA      1  2014   Multiple          80              ARTERIAL ROAD
#
#       National Remoteness Areas Christmas Period Easter Period Day of week  \
# 0      Inner Regional Australia               No            No     Weekday
# 2      Outer Regional Australia               No            No     Weekday
# 4      Outer Regional Australia               No            No     Weekday
# 5     Major Cities of Australia               No            No     Weekend
# 6     Major Cities of Australia               No            No     Weekend
# ...                         ...              ...           ...         ...
# 8936   Inner Regional Australia               No            No     Weekday
# 8944  Major Cities of Australia              Yes            No     Weekday
# 8948  Major Cities of Australia               No            No     Weekday
# 8950  Major Cities of Australia               No            No     Weekday
# 8954  Major Cities of Australia               No            No     Weekend
#
#      Time of Day
# 0            Day
# 2            Day
# 4            Day
# 5            Day
# 6            Day
# ...          ...
# 8936         Day
# 8944         Day
# 8948       Night
# 8950         Day
# 8954       Night
#
# [7126 rows x 11 columns]

# %%
cleaned_ardd_data = cleaned_ardd_data1.rename(columns={'Crash Type': 'crash_type','Bus \nInvolvement': 'bus_involvement','Heavy Rigid Truck Involvement': 'heavy_rigid_truck_involvement','Articulated Truck Involvement': 'articulated_truck_involvement','Speed Limit': 'speed_limit','Christmas Period': 'christmas_period','Easter Period': 'easter_period','Day of week': 'day_of_week'})

# %%
# Set features. 
X = cleaned_ardd_data.drop("crash_type", axis=1)
y = cleaned_ardd_data["crash_type"]
print(X.shape, y.shape)
# Out:
# (7126, 10) (7126,)

# %%
X["speed_limit"].unique()
# Out:
# array(['90', '80', '100', '70', '60', '110', '50', '130', '40', '5', '10',
#        '30', '25', '20', 40, '75'], dtype=object)

# %%
X["Year"].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014])

# %%
y.unique()
# Out:
# array(['Single', 'Multiple'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()

transformed_X = onehotencoder.fit_transform(X[["State","christmas_period", "National Road Type","National Remoteness Areas","easter_period","day_of_week","Time of Day"]])
print(transformed_X)
# Out:
#   (0, 1)	1.0
#   (0, 8)	1.0
#   (0, 13)	1.0
#   (0, 23)	1.0
#   (0, 28)	1.0
#   (0, 30)	1.0
#   (0, 32)	1.0
#   (1, 4)	1.0
#   (1, 8)	1.0
#   (1, 19)	1.0
#   (1, 25)	1.0
#   (1, 28)	1.0
#   (1, 30)	1.0
#   (1, 32)	1.0
#   (2, 5)	1.0
#   (2, 8)	1.0
#   (2, 19)	1.0
#   (2, 25)	1.0
#   (2, 28)	1.0
#   (2, 30)	1.0
#   (2, 32)	1.0
#   (3, 1)	1.0
#   (3, 8)	1.0
#   (3, 19)	1.0
#   (3, 24)	1.0
#   :	:
#   (7122, 24)	1.0
#   (7122, 28)	1.0
#   (7122, 30)	1.0
#   (7122, 32)	1.0
#   (7123, 4)	1.0
#   (7123, 8)	1.0
#   (7123, 17)	1.0
#   (7123, 24)	1.0
#   (7123, 28)	1.0
#   (7123, 30)	1.0
#   (7123, 33)	1.0
#   (7124, 4)	1.0
#   (7124, 8)	1.0
#   (7124, 17)	1.0
#   (7124, 24)	1.0
#   (7124, 28)	1.0
#   (7124, 30)	1.0
#   (7124, 32)	1.0
#   (7125, 7)	1.0
#   (7125, 8)	1.0
#   (7125, 11)	1.0
#   (7125, 24)	1.0
#   (7125, 28)	1.0
#   (7125, 31)	1.0
#   (7125, 33)	1.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
numeric_features = ["Month", "Year","speed_limit"]
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]
)

categorical_features = ["State","christmas_period", "National Road Type","National Remoteness Areas","easter_period","day_of_week","Time of Day"]
categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", LogisticRegression())]
)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_test, y_test))
# Out:
# model score: 0.627
# /Users/andrianichristanty/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    transformed_X, encoded_y, random_state=1)

# %%
X_train
# Out:
# <5344x34 sparse matrix of type '<class 'numpy.float64'>'
# 	with 37408 stored elements in Compressed Sparse Row format>

# %%
y_train
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
y_test
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
X_test
# Out:
# <1782x34 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12474 stored elements in Compressed Sparse Row format>

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.686564371257485

# %%
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.686564371257485

# %%
print(f"Training Data Score: {clf.score(X_train, y_train)}")
print(f"Testing Data Score: {clf.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.686564371257485
# Testing Data Score: 0.6060606060606061
