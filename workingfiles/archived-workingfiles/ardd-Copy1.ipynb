# %%
# IMPORT Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
# Import the Australian Road Death Dataset
ardd_data = pd.read_csv('../Resources/ardd_fatal_crashes.csv')
ardd_data
# Out:
# /var/folders/h4/v2g57xvj6mz75vxd96qdxsqw0000gn/T/ipykernel_47548/2073364016.py:2: DtypeWarning: Columns (11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   ardd_data = pd.read_csv('../Resources/ardd_fatal_crashes.csv')
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20221049   NSW      3  2022    Tuesday  06:50     Single
# 1      20222018   Vic      3  2022     Friday  13:05   Multiple
# 2      20224006    SA      3  2022     Friday  09:30   Multiple
# 3      20225008    WA      3  2022   Saturday  06:00     Single
# 4      20226010   Tas      3  2022    Tuesday  11:47     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 48116  19892204   Vic      1  1989     Friday  13:20     Single
# 48117  19893326   Qld      1  1989     Monday  09:00   Multiple
# 48118  19892576   Vic      1  1989     Friday  17:15   Multiple
# 48119  19891122   NSW      1  1989    Tuesday  14:10   Multiple
# 48120  19894151    SA      1  1989  Wednesday  11:45   Multiple
#
#        Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  \
# 0                      1                No                           Yes
# 1                      1                -9                            -9
# 2                      1                No                            No
# 3                      1                No                            No
# 4                      1                No                            No
# ...                  ...               ...                           ...
# 48116                  1                No                            No
# 48117                  1                No                            -9
# 48118                  1                No                            No
# 48119                  1                No                            -9
# 48120                  1                No                            -9
#
#       Articulated Truck Involvement Speed Limit  National Remoteness Areas  \
# 0                                No          90   Inner Regional Australia
# 1                                -9          -9  Major Cities of Australia
# 2                                No          80   Outer Regional Australia
# 3                                No         110                        NaN
# 4                                No         100   Outer Regional Australia
# ...                             ...         ...                        ...
# 48116                            No          60                        NaN
# 48117                            No          60                        NaN
# 48118                            No          60                        NaN
# 48119                            No          60                        NaN
# 48120                            No          60                        NaN
#
#                    SA4 Name 2016 National LGA Name 2017  \
# 0                 Capital Region            Eurobodalla
# 1              Melbourne - Inner       Port Phillip (C)
# 2      South Australia - Outback       Port Augusta (C)
# 3                            NaN                    NaN
# 4      Launceston and North East        Break O'Day (M)
# ...                          ...                    ...
# 48116                        NaN                    NaN
# 48117                        NaN                    NaN
# 48118                        NaN                    NaN
# 48119                        NaN                    NaN
# 48120                        NaN                    NaN
#
#               National Road Type Christmas Period Easter Period Day of week  \
# 0                  Arterial Road               No            No     Weekday
# 1                     Local Road               No            No     Weekday
# 2      National or State Highway               No            No     Weekday
# 3                            NaN               No            No     Weekend
# 4      National or State Highway               No            No     Weekday
# ...                          ...              ...           ...         ...
# 48116                        NaN               No            No     Weekday
# 48117                        NaN               No            No     Weekday
# 48118                        NaN               No            No     Weekday
# 48119                        NaN               No            No     Weekday
# 48120                        NaN               No            No     Weekday
#
#       Time of Day
# 0             Day
# 1             Day
# 2             Day
# 3             Day
# 4             Day
# ...           ...
# 48116         Day
# 48117         Day
# 48118         Day
# 48119         Day
# 48120         Day
#
# [48121 rows x 20 columns]

# %%
#check the shape of the original CSV
ardd_data.shape
# Out:
# (48121, 20)

# %%
# according to the documentation, -9 would mean "Unknown", however after data exploration those data will be of no use for our ML model
ardd_data = ardd_data.replace("-9", np.nan)

# %%
#drop rows containing null values
cleaned_ardd_data = ardd_data.dropna()

# %%
#check shape 
cleaned_ardd_data.shape
# Out:
# (7122, 20)

# %%
cleaned_ardd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7122 entries, 0 to 8954
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       7122 non-null   int64
#  1   State                          7122 non-null   object
#  2   Month                          7122 non-null   int64
#  3   Year                           7122 non-null   int64
#  4   Dayweek                        7122 non-null   object
#  5   Time                           7122 non-null   object
#  6   Crash Type                     7122 non-null   object
#  7   Number Fatalities              7122 non-null   int64
#  8   Bus
# Involvement               7122 non-null   object
#  9   Heavy Rigid Truck Involvement  7122 non-null   object
#  10  Articulated Truck Involvement  7122 non-null   object
#  11  Speed Limit                    7122 non-null   object
#  12  National Remoteness Areas      7122 non-null   object
#  13  SA4 Name 2016                  7122 non-null   object
#  14  National LGA Name 2017         7122 non-null   object
#  15  National Road Type             7122 non-null   object
#  16  Christmas Period               7122 non-null   object
#  17  Easter Period                  7122 non-null   object
#  18  Day of week                    7122 non-null   object
#  19  Time of Day                    7122 non-null   object
# dtypes: int64(4), object(16)
# memory usage: 1.1+ MB

# %%
cleaned_ardd_data1 = cleaned_ardd_data.filter(['State','Month','Year','Crash Type','Bus \nInvolvement','Heavy Rigid Truck Involvement','Articulated Truck Involvement','Speed Limit','National Remoteness Areas','National Road Type','Christmas Period','Easter Period','Day of week'])
cleaned_ardd_data1.head(20)
# Out:
#    State  Month  Year Crash Type Bus \nInvolvement  \
# 0    NSW      3  2022     Single                No
# 2     SA      3  2022   Multiple                No
# 4    Tas      3  2022     Single                No
# 5    NSW      3  2022   Multiple                No
# 6    NSW      3  2022     Single                No
# 9    Qld      3  2022     Single                No
# 10   Qld      3  2022     Single                No
# 11   NSW      3  2022     Single                No
# 12   NSW      3  2022   Multiple                No
# 13   Qld      3  2022     Single                No
# 15   Qld      3  2022   Multiple                No
# 16   Qld      3  2022     Single                No
# 18   NSW      3  2022   Multiple                No
# 19   NSW      3  2022     Single                No
# 20    SA      3  2022     Single                No
# 22    SA      3  2022     Single                No
# 24   Tas      3  2022   Multiple                No
# 25   Tas      3  2022   Multiple                No
# 26   NSW      3  2022   Multiple                No
# 27   NSW      3  2022     Single               Yes
#
#    Heavy Rigid Truck Involvement Articulated Truck Involvement Speed Limit  \
# 0                            Yes                            No          90
# 2                             No                            No          80
# 4                             No                            No         100
# 5                             No                            No          70
# 6                             No                            No          60
# 9                             No                            No         100
# 10                            No                            No          60
# 11                            No                            No          70
# 12                            No                            No         110
# 13                            No                            No          50
# 15                            No                           Yes          60
# 16                            No                            No          80
# 18                            No                            No          50
# 19                            No                            No         100
# 20                            No                            No         110
# 22                            No                            No          50
# 24                            No                            No         100
# 25                           Yes                            No         110
# 26                           Yes                            No          80
# 27                            No                            No          60
#
#     National Remoteness Areas         National Road Type Christmas Period  \
# 0    Inner Regional Australia              Arterial Road               No
# 2    Outer Regional Australia  National or State Highway               No
# 4    Outer Regional Australia  National or State Highway               No
# 5   Major Cities of Australia  National or State Highway               No
# 6   Major Cities of Australia              Arterial Road               No
# 9    Inner Regional Australia                 Local Road               No
# 10  Major Cities of Australia                 Local Road               No
# 11   Inner Regional Australia              Arterial Road               No
# 12   Inner Regional Australia  National or State Highway               No
# 13   Outer Regional Australia                 Local Road               No
# 15   Outer Regional Australia  National or State Highway               No
# 16  Major Cities of Australia  National or State Highway               No
# 18   Inner Regional Australia                 Local Road               No
# 19           Remote Australia              Arterial Road               No
# 20   Outer Regional Australia  National or State Highway               No
# 22   Inner Regional Australia                 Local Road               No
# 24   Outer Regional Australia             Collector Road               No
# 25   Inner Regional Australia  National or State Highway               No
# 26   Inner Regional Australia                 Local Road               No
# 27  Major Cities of Australia  National or State Highway               No
#
#    Easter Period Day of week
# 0             No     Weekday
# 2             No     Weekday
# 4             No     Weekday
# 5             No     Weekend
# 6             No     Weekend
# 9             No     Weekday
# 10            No     Weekday
# 11            No     Weekday
# 12            No     Weekday
# 13            No     Weekday
# 15            No     Weekday
# 16            No     Weekday
# 18            No     Weekday
# 19            No     Weekday
# 20            No     Weekend
# 22            No     Weekend
# 24            No     Weekday
# 25            No     Weekday
# 26            No     Weekday
# 27            No     Weekday

# %%
cleaned_ardd_data2 = cleaned_ardd_data.filter(['State','Month','Year','Crash Type','Speed Limit','National Remoteness Areas','National Road Type','Christmas Period','Easter Period','Day of week'])
cleaned_ardd_data2.head(20)
# Out:
#    State  Month  Year Crash Type Speed Limit  National Remoteness Areas  \
# 0    NSW      3  2022     Single          90   Inner Regional Australia
# 2     SA      3  2022   Multiple          80   Outer Regional Australia
# 4    Tas      3  2022     Single         100   Outer Regional Australia
# 5    NSW      3  2022   Multiple          70  Major Cities of Australia
# 6    NSW      3  2022     Single          60  Major Cities of Australia
# 9    Qld      3  2022     Single         100   Inner Regional Australia
# 10   Qld      3  2022     Single          60  Major Cities of Australia
# 11   NSW      3  2022     Single          70   Inner Regional Australia
# 12   NSW      3  2022   Multiple         110   Inner Regional Australia
# 13   Qld      3  2022     Single          50   Outer Regional Australia
# 15   Qld      3  2022   Multiple          60   Outer Regional Australia
# 16   Qld      3  2022     Single          80  Major Cities of Australia
# 18   NSW      3  2022   Multiple          50   Inner Regional Australia
# 19   NSW      3  2022     Single         100           Remote Australia
# 20    SA      3  2022     Single         110   Outer Regional Australia
# 22    SA      3  2022     Single          50   Inner Regional Australia
# 24   Tas      3  2022   Multiple         100   Outer Regional Australia
# 25   Tas      3  2022   Multiple         110   Inner Regional Australia
# 26   NSW      3  2022   Multiple          80   Inner Regional Australia
# 27   NSW      3  2022     Single          60  Major Cities of Australia
#
#            National Road Type Christmas Period Easter Period Day of week
# 0               Arterial Road               No            No     Weekday
# 2   National or State Highway               No            No     Weekday
# 4   National or State Highway               No            No     Weekday
# 5   National or State Highway               No            No     Weekend
# 6               Arterial Road               No            No     Weekend
# 9                  Local Road               No            No     Weekday
# 10                 Local Road               No            No     Weekday
# 11              Arterial Road               No            No     Weekday
# 12  National or State Highway               No            No     Weekday
# 13                 Local Road               No            No     Weekday
# 15  National or State Highway               No            No     Weekday
# 16  National or State Highway               No            No     Weekday
# 18                 Local Road               No            No     Weekday
# 19              Arterial Road               No            No     Weekday
# 20  National or State Highway               No            No     Weekend
# 22                 Local Road               No            No     Weekend
# 24             Collector Road               No            No     Weekday
# 25  National or State Highway               No            No     Weekday
# 26                 Local Road               No            No     Weekday
# 27  National or State Highway               No            No     Weekday

# %%
cleaned_ardd_data = cleaned_ardd_data.rename(columns={'Crash Type': 'crash_type','Bus \nInvolvement': 'bus_involvement','Heavy Rigid Truck Involvement': 'heavy_rigid_truck_involvement','Articulated Truck Involvement': 'articulated_truck_involvement','Speed Limit': 'speed_limit','National Remoteness Areas': 'national_remoteness_area','National Road Type': 'national_road_type','Christmas Period': 'christmas_period','Easter Period': 'easter_period','Day of week': 'day_of_week'})

# %%
cleaned_ardd_data2 = cleaned_ardd_data2.rename(columns={'Crash Type': 'crash_type','Speed Limit': 'speed_limit','National Remoteness Areas': 'national_remoteness_area','National Road Type': 'national_road_type','Christmas Period': 'christmas_period','Easter Period': 'easter_period','Day of week': 'day_of_week'})
cleaned_ardd_data2
# Out:
#      State  Month  Year crash_type speed_limit   national_remoteness_area  \
# 0      NSW      3  2022     Single          90   Inner Regional Australia
# 2       SA      3  2022   Multiple          80   Outer Regional Australia
# 4      Tas      3  2022     Single         100   Outer Regional Australia
# 5      NSW      3  2022   Multiple          70  Major Cities of Australia
# 6      NSW      3  2022     Single          60  Major Cities of Australia
# ...    ...    ...   ...        ...         ...                        ...
# 8936   Tas      1  2014   Multiple          80   Inner Regional Australia
# 8944    WA      1  2014     Single         100  Major Cities of Australia
# 8948    SA      1  2014     Single          50  Major Cities of Australia
# 8950    SA      1  2014     Single          50  Major Cities of Australia
# 8954    WA      1  2014   Multiple          80  Major Cities of Australia
#
#              national_road_type christmas_period easter_period day_of_week
# 0                 Arterial Road               No            No     Weekday
# 2     National or State Highway               No            No     Weekday
# 4     National or State Highway               No            No     Weekday
# 5     National or State Highway               No            No     Weekend
# 6                 Arterial Road               No            No     Weekend
# ...                         ...              ...           ...         ...
# 8936  National or State Highway               No            No     Weekday
# 8944  NATIONAL OR STATE HIGHWAY              Yes            No     Weekday
# 8948                 Local Road               No            No     Weekday
# 8950                 Local Road               No            No     Weekday
# 8954              ARTERIAL ROAD               No            No     Weekend
#
# [7122 rows x 10 columns]

# %%
# Set features. 
X = cleaned_ardd_data.drop("crash_type", axis=1)
y = cleaned_ardd_data["crash_type"]
print(X.shape, y.shape)
# Out:
# (7122, 19) (7122,)

# %%
# Set features. 
X2 = cleaned_ardd_data2.drop("crash_type", axis=1)
y2 = cleaned_ardd_data2["crash_type"]
print(X2.shape, y2.shape)
# Out:
# (7122, 9) (7122,)

# %%
X
# Out:
#       Crash ID State  Month  Year    Dayweek   Time  Number Fatalities  \
# 0     20221049   NSW      3  2022    Tuesday  06:50                  1
# 2     20224006    SA      3  2022     Friday  09:30                  1
# 4     20226010   Tas      3  2022    Tuesday  11:47                  1
# 5     20221025   NSW      3  2022     Sunday  11:10                  1
# 6     20221045   NSW      3  2022     Sunday  15:25                  1
# ...        ...   ...    ...   ...        ...    ...                ...
# 8936  20146015   Tas      1  2014     Monday  12:10                  1
# 8944  20145108    WA      1  2014  Wednesday  11:47                  1
# 8948  20144007    SA      1  2014    Tuesday  20:00                  1
# 8950  20144022    SA      1  2014     Monday  09:35                  1
# 8954  20145053    WA      1  2014     Monday  00:10                  1
#
#      bus_involvement heavy_rigid_truck_involvement  \
# 0                 No                           Yes
# 2                 No                            No
# 4                 No                            No
# 5                 No                            No
# 6                 No                            No
# ...              ...                           ...
# 8936              No                            No
# 8944              No                            No
# 8948              No                            No
# 8950              No                            No
# 8954              No                            No
#
#      articulated_truck_involvement speed_limit   national_remoteness_area  \
# 0                               No          90   Inner Regional Australia
# 2                               No          80   Outer Regional Australia
# 4                               No         100   Outer Regional Australia
# 5                               No          70  Major Cities of Australia
# 6                               No          60  Major Cities of Australia
# ...                            ...         ...                        ...
# 8936                            No          80   Inner Regional Australia
# 8944                            No         100  Major Cities of Australia
# 8948                            No          50  Major Cities of Australia
# 8950                            No          50  Major Cities of Australia
# 8954                            No          80  Major Cities of Australia
#
#                   SA4 Name 2016 National LGA Name 2017  \
# 0                Capital Region            Eurobodalla
# 2     South Australia - Outback       Port Augusta (C)
# 4     Launceston and North East        Break O'Day (M)
# 5           Sydney - Sutherland             Sutherland
# 6           Sydney - Inner West             Inner West
# ...                         ...                    ...
# 8936                     Hobart        Kingborough (M)
# 8944         Perth - South East            Belmont (C)
# 8948           Adelaide - North           Playford (C)
# 8950           Adelaide - North     Tea Tree Gully (C)
# 8954         Perth - South West           Cockburn (C)
#
#              national_road_type christmas_period easter_period day_of_week  \
# 0                 Arterial Road               No            No     Weekday
# 2     National or State Highway               No            No     Weekday
# 4     National or State Highway               No            No     Weekday
# 5     National or State Highway               No            No     Weekend
# 6                 Arterial Road               No            No     Weekend
# ...                         ...              ...           ...         ...
# 8936  National or State Highway               No            No     Weekday
# 8944  NATIONAL OR STATE HIGHWAY              Yes            No     Weekday
# 8948                 Local Road               No            No     Weekday
# 8950                 Local Road               No            No     Weekday
# 8954              ARTERIAL ROAD               No            No     Weekend
#
#      Time of Day
# 0            Day
# 2            Day
# 4            Day
# 5            Day
# 6            Day
# ...          ...
# 8936         Day
# 8944         Day
# 8948       Night
# 8950         Day
# 8954       Night
#
# [7122 rows x 19 columns]

# %%
y.unique()
# Out:
# array(['Single', 'Multiple'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()

transformed_X = onehotencoder.fit_transform(X[["State", "Month","Year", "bus_involvement","heavy_rigid_truck_involvement", "articulated_truck_involvement", "speed_limit", "national_remoteness_area", "national_road_type","christmas_period", "easter_period","day_of_week"]])
print(transformed_X)
# Out:
#   (0, 1)	1.0
#   (0, 10)	1.0
#   (0, 28)	1.0
#   (0, 29)	1.0
#   (0, 32)	1.0
#   (0, 33)	1.0
#   (0, 49)	1.0
#   (0, 52)	1.0
#   (0, 60)	1.0
#   (0, 70)	1.0
#   (0, 72)	1.0
#   (0, 74)	1.0
#   (1, 4)	1.0
#   (1, 10)	1.0
#   (1, 28)	1.0
#   (1, 29)	1.0
#   (1, 31)	1.0
#   (1, 33)	1.0
#   (1, 48)	1.0
#   (1, 54)	1.0
#   (1, 66)	1.0
#   (1, 70)	1.0
#   (1, 72)	1.0
#   (1, 74)	1.0
#   (2, 5)	1.0
#   :	:
#   (7119, 74)	1.0
#   (7120, 4)	1.0
#   (7120, 8)	1.0
#   (7120, 20)	1.0
#   (7120, 29)	1.0
#   (7120, 31)	1.0
#   (7120, 33)	1.0
#   (7120, 44)	1.0
#   (7120, 53)	1.0
#   (7120, 64)	1.0
#   (7120, 70)	1.0
#   (7120, 72)	1.0
#   (7120, 74)	1.0
#   (7121, 7)	1.0
#   (7121, 8)	1.0
#   (7121, 20)	1.0
#   (7121, 29)	1.0
#   (7121, 31)	1.0
#   (7121, 33)	1.0
#   (7121, 48)	1.0
#   (7121, 53)	1.0
#   (7121, 58)	1.0
#   (7121, 70)	1.0
#   (7121, 72)	1.0
#   (7121, 75)	1.0

# %%
transformed_X2 = onehotencoder.fit_transform(X2[["State", "Month","Year", "speed_limit", "national_remoteness_area", "national_road_type","christmas_period", "easter_period","day_of_week"]])
print(transformed_X2)
# Out:
#   (0, 1)	1.0
#   (0, 10)	1.0
#   (0, 28)	1.0
#   (0, 43)	1.0
#   (0, 46)	1.0
#   (0, 54)	1.0
#   (0, 64)	1.0
#   (0, 66)	1.0
#   (0, 68)	1.0
#   (1, 4)	1.0
#   (1, 10)	1.0
#   (1, 28)	1.0
#   (1, 42)	1.0
#   (1, 48)	1.0
#   (1, 60)	1.0
#   (1, 64)	1.0
#   (1, 66)	1.0
#   (1, 68)	1.0
#   (2, 5)	1.0
#   (2, 10)	1.0
#   (2, 28)	1.0
#   (2, 30)	1.0
#   (2, 48)	1.0
#   (2, 60)	1.0
#   (2, 64)	1.0
#   :	:
#   (7119, 20)	1.0
#   (7119, 38)	1.0
#   (7119, 47)	1.0
#   (7119, 58)	1.0
#   (7119, 64)	1.0
#   (7119, 66)	1.0
#   (7119, 68)	1.0
#   (7120, 4)	1.0
#   (7120, 8)	1.0
#   (7120, 20)	1.0
#   (7120, 38)	1.0
#   (7120, 47)	1.0
#   (7120, 58)	1.0
#   (7120, 64)	1.0
#   (7120, 66)	1.0
#   (7120, 68)	1.0
#   (7121, 7)	1.0
#   (7121, 8)	1.0
#   (7121, 20)	1.0
#   (7121, 42)	1.0
#   (7121, 47)	1.0
#   (7121, 52)	1.0
#   (7121, 64)	1.0
#   (7121, 66)	1.0
#   (7121, 69)	1.0

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
label_encoder.fit(y2)
encoded_y2 = label_encoder.transform(y2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    transformed_X, encoded_y, random_state=1)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    transformed_X2, encoded_y2, random_state=1)

# %%
X_train
# Out:
# <5341x76 sparse matrix of type '<class 'numpy.float64'>'
# 	with 64092 stored elements in Compressed Sparse Row format>

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
X_test
# Out:
# <1781x76 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21372 stored elements in Compressed Sparse Row format>

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9717281407976034

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train2, y_train2)
clf.score(X_train2, y_train2)
# Out:
# 0.9574985957685826

# %%
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9717281407976034

# %%
print(f"Training Data Score: {clf.score(X_train, y_train)}")
print(f"Testing Data Score: {clf.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9717281407976034
# Testing Data Score: 0.6019090398652442

# %%
print(f"Training Data Score: {clf.score(X_train2, y_train2)}")
print(f"Testing Data Score: {clf.score(X_test2, y_test2)}")
# Out:
# Training Data Score: 0.9574985957685826
# Testing Data Score: 0.5429533969679955

# %%
y.value_counts()
# Out:
# Single      4089
# Multiple    3033
# Name: crash_type, dtype: int64

# %%
clf.feature_importances_
# Out:
# array([0.00255965, 0.02933954, 0.00453226, 0.02153416, 0.01707256,
#        0.00848199, 0.02914625, 0.02004237, 0.02600313, 0.02134031,
#        0.03108317, 0.02739662, 0.02738458, 0.02605259, 0.02620477,
#        0.0242366 , 0.02228395, 0.02719232, 0.02580141, 0.02337367,
#        0.01105383, 0.03180715, 0.02837682, 0.02631093, 0.02468708,
#        0.02733057, 0.0334047 , 0.02682318, 0.01198375, 0.00071518,
#        0.02784843, 0.01202893, 0.00026532, 0.        , 0.        ,
#        0.00011755, 0.00452029, 0.00042261, 0.01385216, 0.01811257,
#        0.01652119, 0.        , 0.01807554, 0.00802356, 0.00037733,
#        0.        , 0.01539469, 0.01974444, 0.01241838, 0.00520936,
#        0.00648512, 0.00066246, 0.00499244, 0.00485283, 0.02246544,
#        0.        , 0.01198908, 0.00383184, 0.01549063, 0.0035585 ,
#        0.01601891, 0.        , 0.01771467, 0.00103304, 0.00432616,
#        0.00812237, 0.00235165, 0.00486657, 0.01382256, 0.02092827])

# %%
top_df = pd.DataFrame({"column":X_train.columns, "importance":clf.feature_importances_}).sort_values(by="importance")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 top_df = pd.DataFrame({"column":X_train.columns, "importance":clf.feature_importances_}).sort_values(by="importance")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/base.py:687, in spmatrix.__getattr__(self, attr)
#     685     return self.getnnz()
#     686 else:
# --> 687     raise AttributeError(attr + " not found")
#
# AttributeError: columns not found
